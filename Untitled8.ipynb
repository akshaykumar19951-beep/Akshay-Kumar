# %%
import matplotlib.pyplot as pl
from PIL import Image , ImageOps

# %%
import pandas as pd

# %%
import pandas as pd

# Path to the CSV file
csv_path = r"C:\Users\273309\OneDrive\Desktop\creditcard.csv"  

# Read the CSV file directly using pandas
df_creditcard = pd.read_csv(csv_path)

# Now df_creditcard contains the data from creditcard.csv

# %%
df_creditcard.shape
# Out:
# (284807, 31)

# %%
# Two Data Structures
# Data Frame
# Series

type(df_creditcard)
# Out:
# pandas.core.frame.DataFrame

# %%
df_creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df_creditcard.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df_creditcard.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df_creditcard = df_creditcard.loc[:, ~df_creditcard.columns.str.lower().isin(['cabin'])]

# %%
df_creditcard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Printing statistical Report
df_creditcard.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
obj_cols = df.select_dtypes(include="object")

if obj_cols.shape[1] > 0:
    obj_cols.describe()
else:
    print("No object (categorical) columns found in this dataset.")
# Out:
# No object (categorical) columns found in this dataset.

# %%
df.dtypes.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
if df.shape[1] > 0:
    display(df.describe())
else:
    print("DataFrame has no columns — reload data")
# Out:
# DataFrame has no columns — reload data

# %%
# Reload
df = pd.read_csv(r"C:\Users\273309\OneDrive\Desktop\creditcard.csv")

# Verify
df.info()

# Describe
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# To check null values

df_creditcard.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df_creditcard["Time"].mean()
# Out:
# 94813.85957508067

# %%
# To check null values
df_creditcard.isnull().sum () / df_creditcard.shape[0] * 100
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %%
# Data Analysis
# You need to mention these null values in your report

# Machine learning
# Fill these values

# How to fill?
# Ffill
# Bfill
# Mean/Median/Mode

# %%
def df_creditcard(df):
    # Function body goes here
    pass  # Replace with your actual function code

# %%
# If you're trying to create a pandas DataFrame:
import pandas as pd
df = pd.DataFrame()

# Or if you're trying to add a type hint in a function:
def some_function(df: pd.DataFrame):
    # function code here
    pass

# %%
# Data Analysis part
# Check for null values and print summary
null_counts = df.isnull().sum()
print("Null values in the dataset:")
print(null_counts[null_counts > 0])
print("\nPercentage of null values:")
print((null_counts[null_counts > 0] / len(df) * 100).round(2))
# Out:
# Null values in the dataset:
# Series([], dtype: float64)
#
# Percentage of null values:
# Series([], dtype: float64)

# %%
df_processed = df.copy()

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df[['Amount', 'Time']])
plt.title("Boxplot for Amount and Time")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['Time'], df['Amount'], alpha=0.3)
plt.xlabel("Time")
plt.ylabel("Amount")
plt.title("Scatter Plot: Time vs Amount")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['Class'], df['Amount'], alpha=0.3)
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Amount")
plt.title("Amount vs Class")
plt.show()

# %%
def plot_box(column):
    sns.boxplot(x=df[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

plot_box("Amount")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))
sns.countplot(x='Class', data=df)
plt.title("Transaction Class Distribution")
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(x='Class', data=df)

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom')

plt.title("Fraud vs Normal Transactions")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
def plot_count(column):
    sns.countplot(x=column, data=df)
    plt.title(f"Countplot of {column}")
    plt.show()

plot_count("Class")

# %%
class_percent = df['Class'].value_counts(normalize=True) * 100
print(class_percent)
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title("Histogram of Transaction Amount")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Time'], bins=50)
plt.title("Histogram of Transaction Time")
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='Amount', hue='Class', bins=50, kde=True)
plt.title("Amount Distribution by Class")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Amount'], bins=50)
plt.title("Histogram of Amount")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()

# %%
# Fraud amounts are highly skewed
plt.figure(figsize=(8, 5))
sns.histplot(df['Amount'], bins=50)
plt.xscale('log')
plt.title("Log-Scaled Histogram of Amount")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.boxplot(x=df['Amount'])
plt.title("Boxplot of Transaction Amount")
plt.show()

# %%
# This clearly shows outliers in fraud transactions.
plt.figure(figsize=(8, 4))
sns.boxplot(x='Class', y='Amount', data=df)
plt.title("Amount Distribution by Class")
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Amount")
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df[['Amount', 'Time']])
plt.title("Boxplot of Amount and Time")
plt.show()

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include='number')

# %%
numeric_df.shape
numeric_df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
corr_matrix = numeric_df.corr()
corr_matrix
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap (Numeric Features)")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select numeric columns
numeric_df = df.select_dtypes(include='number')

# Correlation matrix
corr_matrix = numeric_df.corr()

# Heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap (Credit Card Dataset)")
plt.show()

# %%
plt.figure(figsize=(6, 10))
sns.heatmap(
    numeric_df.corr()[['Class']].sort_values(by='Class', ascending=False),
    annot=True,
    cmap='coolwarm',
    center=0
)
plt.title("Feature Correlation with Class")
plt.show()

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0, square=True)
plt.show()

# %%
df_creditcard
# Out:
# <function __main__.df_creditcard(df)>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.violinplot(x=df['Amount'])
plt.title("Violin Plot of Transaction Amount")
plt.show()

# %%
# Fraud analysis
plt.figure(figsize=(8, 5))
sns.violinplot(x='Class', y='Amount', data=df)
plt.title("Transaction Amount Distribution by Class")
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Amount")
plt.show()

# %%
# Violin Plot with Quartiles
plt.figure(figsize=(8, 5))
sns.violinplot(x='Class', y='Amount', data=df, inner='quartile')
plt.title("Violin Plot with Quartiles")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

normal = df.loc[df['Class'] == 0, 'Amount']
fraud = df.loc[df['Class'] == 1, 'Amount']

plt.figure(figsize=(8, 5))
sns.kdeplot(normal, label='Normal', fill=True)
sns.kdeplot(fraud, label='Fraud', fill=True)

plt.title("Amount Distribution Comparison")
plt.xlabel("Amount")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(
    data=df,
    x='Amount',
    hue='Class',
    fill=True,
    common_norm=False
)
plt.xscale('log')
plt.title("Log-Scaled Amount Distribution by Class")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 5))
sns.kdeplot(
    data=df,
    x='Amount',
    hue='Class',
    fill=True,
    common_norm=False
)
plt.xscale('log')
plt.title("Log-Scaled Amount Distribution by Class")
plt.xlabel("Transaction Amount (log scale)")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(
    data=df,
    x='Amount',
    hue='Class',
    bins=50,
    kde=True,
    element='step'
)
plt.xscale('log')
plt.title("Histogram of Amount by Class")
plt.show()

# %%
from scipy.stats import ks_2samp

normal = df.loc[df['Class'] == 0, 'Amount']
fraud = df.loc[df['Class'] == 1, 'Amount']

ks_stat, p_value = ks_2samp(normal, fraud)

print("KS Statistic:", ks_stat)
print("P-Value:", p_value)
# Out:
# KS Statistic: 0.27119151307757383
# P-Value: 2.1703053464297685e-32

# %%
df['Amount_log'] = np.log1p(df['Amount'])

# %%
df_fe = df.drop(columns=['Amount'])

# %%
df['Amount_Time'] = df['Amount_log'] * df['Time']

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression(max_iter=1000, class_weight='balanced')
model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.06      0.87      0.12       148
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.92      0.55     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
from imblearn.over_sampling import SMOTE

X = df.drop('Class', axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

print("Before SMOTE:", y_train.value_counts())
print("After SMOTE:", y_train_smote.value_counts())
# Out:
# Before SMOTE: Class
# 0    199020
# 1       344
# Name: count, dtype: int64
# After SMOTE: Class
# 0    199020
# 1    199020
# Name: count, dtype: int64

# %%
class_weight = {0: 1, 1: 20}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    class_weight='balanced',
    n_jobs=-1
)

rf.fit(X_train, y_train)
rf_preds = rf.predict(X_test)

print(classification_report(y_test, rf_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.97      0.71      0.82       148
#
#     accuracy                           1.00     85443
#    macro avg       0.99      0.85      0.91     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline(steps=[
    ('scaler', RobustScaler()),
    ('model', LogisticRegression(
        max_iter=1000,
        class_weight='balanced'
    ))
])

pipeline.fit(X_train, y_train)

pipe_preds = pipeline.predict(X_test)
print(classification_report(y_test, pipe_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.06      0.87      0.12       148
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.92      0.55     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_cols = ['Amount', 'Time', 'V1', 'V2', 'Class']

sns.pairplot(
    df[selected_cols],
    hue='Class',
    diag_kind='kde',
    plot_kws={'alpha': 0.4}
)

plt.show()

# %%
pca_cols = ['V1', 'V2', 'V3', 'V4', 'Class']

sns.pairplot(
    df[pca_cols],
    hue='Class',
    diag_kind='kde'
)

plt.show()

# %%
df_sample = df.sample(5000, random_state=42)

sns.pairplot(
    df_sample[selected_cols],
    hue='Class',
    diag_kind='kde'
)

plt.show()

# %%
sns.pairplot(
    df[selected_cols],
    hue='Class',
    diag_kind='hist'
)

plt.show()
